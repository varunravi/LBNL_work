# %%
# %matplotlib inline
import numpy as np
from astropy.io import fits
import matplotlib.pyplot as plt
import tensorflow as tf
import importlib.util
from pathlib import Path
# Out:
# C:\Users\Andrew\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
hdulist = fits.open('legacysurvey-0001m002-ccds.fits')

# %%
print(type(hdulist), len(hdulist))
print(type(hdulist[0]), type(hdulist[1]))
print(hdulist.fileinfo(0), '\n')
print(hdulist.fileinfo(1), '\n')
print(hdulist.info(), '\n')
# print(hdulist[1].data.formats)
# print(hdulist[1].data.field)
# Out:
# <class 'astropy.io.fits.hdu.hdulist.HDUList'> 2
# <class 'astropy.io.fits.hdu.image.PrimaryHDU'> <class 'astropy.io.fits.hdu.table.BinTableHDU'>
# {'file': <astropy.io.fits.file._File <_io.FileIO name='legacysurvey-0001m002-ccds.fits' mode='rb' closefd=True>>, 'filemode': 'readonly', 'hdrLoc': 0, 'datLoc': 8640, 'datSpan': 0, 'filename': 'legacysurvey-0001m002-ccds.fits', 'resized': False}
#
# {'file': <astropy.io.fits.file._File <_io.FileIO name='legacysurvey-0001m002-ccds.fits' mode='rb' closefd=True>>, 'filemode': 'readonly', 'hdrLoc': 8640, 'datLoc': 20160, 'datSpan': 37440, 'filename': 'legacysurvey-0001m002-ccds.fits', 'resized': False}
#
# Filename: legacysurvey-0001m002-ccds.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      72   ()
# ...

# %%
# downloaded from 'cutout service'
test = fits.open('cutout_190.1086_1.2005.fits')[0].data
print(test.shape)

plt.figure(figsize=(10,7))
plt.subplot(131)
plt.imshow(test[0,:,:])
plt.subplot(132)
plt.imshow(test[1,:,:])
plt.subplot(133)
plt.imshow(test[2,:,:])
# Out:
# (3, 256, 256)
